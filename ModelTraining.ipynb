# %%
import os
import pandas as pd
import numpy as np
import torch
import ast
import torchvision.transforms as T
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import torch.nn as nn
from torch.cuda.amp import GradScaler
from torchvision.models.resnet import resnet50
from torchvision.models.detection.faster_rcnn import FasterRCNN_ResNet50_FPN_Weights
from torchvision.models.detection.faster_rcnn import FasterRCNN, FasterRCNN_ResNet50_FPN_V2_Weights, FastRCNNPredictor, FastRCNNConvFCHead
from torchvision.models.detection.backbone_utils import _resnet_fpn_extractor
from torchvision.models.detection.rpn import AnchorGenerator, RPNHead

# %%
def label_encoder(labels):
  encode_label = {"RBC": 1, "trophozoite": 3, "difficult": 4, "ring": 5, "schizont": 6,
                "gametocyte": 7, "leukocyte": 2}
  return [encode_label[l] for l in labels]

def get_transform():
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    return T.Compose(transforms)

# %%
class CustomDataset(Dataset):
  def __init__(self, root_dir, annotation_path, transforms, label_encoder):
    self.root_dir = root_dir
    self.annotations = self.read_ann(annotation_path)
    self.transforms = transforms
    self.encode_label = label_encoder

  def read_ann(self, ann_path):
    df = pd.read_csv(ann_path)
    df['boxes'] = df['boxes'].apply(ast.literal_eval)
    df['label'] = df['label'].apply(ast.literal_eval)
    df['area'] = df['area'].apply(ast.literal_eval)
    return df

  def get_target(self, idx):
    row = self.annotations.iloc[idx]
    boxes = row['boxes']
    labels = self.encode_label(row['label'])
    area = row['area']
    iscrowd = torch.zeros((len(boxes),), dtype=torch.int64)
    target = {
        'boxes': torch.tensor(boxes, dtype=torch.int),
        'labels': torch.tensor(labels),
        'area': torch.tensor(area, dtype=torch.float32),
        'image_id': torch.tensor([idx]),
        'iscrowd': iscrowd
    }
    return target

  def __getitem__(self, idx):
    record = self.annotations.iloc[idx]
    filepath = os.path.join(self.root_dir, record['pathname'][1:])
    target = self.get_target(idx)
    image = Image.open(filepath).convert('RGB')

    if self.transforms is not None:
        image = self.transforms(image)
    return image, target

  def __len__(self):
    return len(self.annotations)

# %%
# %%shell
#
# pip install cython
# # Install pycocotools, the version by default in Colab
# # has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
#
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../

# %%
def custom_anchorgen():
    anchor_sizes = ((32,), (64,), (80,), (94,), (128,))
    aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_sizes)
    return AnchorGenerator(anchor_sizes, aspect_ratios)

def get_fastercnn_v1(num_classes):
  anchor_generator = custom_anchorgen()
  kwarg = {
      'image_mean': [0.7205, 0.7203, 0.7649],
      'image_std': [0.2545, 0.2599, 0.2037],
      # RPN parameters
      'rpn_anchor_generator': anchor_generator,
  }
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT, kwarg=kwarg)
  in_features = model.roi_heads.box_predictor.cls_score.in_features
  model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
  return model

# %%
from engine import evaluate
import utils
from torchvision import transforms as T

# %%
root_dir = "/malaria"
train_path = "/malaria/train.csv"
test_path = "/malaria/test.csv"

train_dataset = CustomDataset(root_dir=root_dir, annotation_path=train_path, transforms=get_transform(), label_encoder=label_encoder)
test_dataset = CustomDataset(root_dir=root_dir, annotation_path=test_path, transforms=get_transform(), label_encoder=label_encoder)

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=6, shuffle=True, num_workers=2,
    collate_fn=utils.collate_fn)

test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=2, shuffle=False, num_workers=2,
    collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

#number of classes in our dataset
num_classes = 8

# get the model using our helper function
model = get_fastercnn_v1(num_classes)

total_params = sum(p.numel() for p in model.parameters())
print(f"{total_params:,} total parameters.")

total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f"{total_trainable_params:,} training parameters.")

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.001,
                            momentum=0.9, weight_decay=0.0001, nesterov=False)

scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.85)

scaler = GradScaler()
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 138MB/s]
# 41,329,911 total parameters.
# 41,107,511 training parameters.

# %%
import math
import sys
import time

import torch
import torchvision.models.detection.mask_rcnn
import utils
from coco_eval import CocoEvaluator
from coco_utils import get_coco_api_from_dataset


def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler=None):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", utils.SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Epoch: [{epoch}]"

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1.0 / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = torch.optim.lr_scheduler.LinearLR(
            optimizer, start_factor=warmup_factor, total_iters=warmup_iters
        )

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        with torch.cuda.amp.autocast(enabled=scaler is not None):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = utils.reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping training")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        if scaler is not None:
            scaler.scale(losses).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            losses.backward()
            optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

# %%
num_epochs = 12

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_loader, device, epoch, scaler=scaler, print_freq=20)
    # update the learning rate
    if epoch >= 1:
      scheduler.step()
    # evaluate on the test dataset
    evaluate(model, test_loader, device=device)
# Out:
# Epoch: [0]  [  0/202]  eta: 0:08:07  lr: 0.000006  loss: 0.4665 (0.4665)  loss_classifier: 0.1845 (0.1845)  loss_box_reg: 0.2597 (0.2597)  loss_objectness: 0.0020 (0.0020)  loss_rpn_box_reg: 0.0203 (0.0203)  time: 2.4139  data: 1.3775  max mem: 7041
# Epoch: [0]  [ 20/202]  eta: 0:03:13  lr: 0.000105  loss: 0.4274 (0.4304)  loss_classifier: 0.1839 (0.1799)  loss_box_reg: 0.2264 (0.2262)  loss_objectness: 0.0057 (0.0058)  loss_rpn_box_reg: 0.0184 (0.0185)  time: 0.9955  data: 0.0854  max mem: 7041
# Epoch: [0]  [ 40/202]  eta: 0:02:41  lr: 0.000205  loss: 0.4216 (0.4300)  loss_classifier: 0.1740 (0.1789)  loss_box_reg: 0.2252 (0.2258)  loss_objectness: 0.0051 (0.0057)  loss_rpn_box_reg: 0.0190 (0.0196)  time: 0.9323  data: 0.0590  max mem: 7041
# Epoch: [0]  [ 60/202]  eta: 0:02:19  lr: 0.000304  loss: 0.4025 (0.4282)  loss_classifier: 0.1726 (0.1777)  loss_box_reg: 0.2076 (0.2245)  loss_objectness: 0.0054 (0.0059)  loss_rpn_box_reg: 0.0197 (0.0201)  time: 0.9432  data: 0.0658  max mem: 7041
# Epoch: [8]  [160/202]  eta: 0:00:40  lr: 0.000321  loss: 0.2845 (0.2787)  loss_classifier: 0.1140 (0.1097)  loss_box_reg: 0.1516 (0.1514)  loss_objectness: 0.0014 (0.0022)  loss_rpn_box_reg: 0.0153 (0.0153)  time: 0.9507  data: 0.0674  max mem: 7043
# Epoch: [8]  [180/202]  eta: 0:00:21  lr: 0.000321  loss: 0.2768 (0.2794)  loss_classifier: 0.1091 (0.1102)  loss_box_reg: 0.1553 (0.1516)  loss_objectness: 0.0013 (0.0023)  loss_rpn_box_reg: 0.0146 (0.0153)  time: 0.9405  data: 0.0693  max mem: 7043
# Epoch: [8]  [200/202]  eta: 0:00:01  lr: 0.000321  loss: 0.2840 (0.2801)  loss_classifier: 0.1105 (0.1106)  loss_box_reg: 0.1565 (0.1520)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0147 (0.0153)  time: 0.9573  data: 0.0717  max mem: 7043
# Epoch: [8]  [201/202]  eta: 0:00:00  lr: 0.000321  loss: 0.2862 (0.2804)  loss_classifier: 0.1105 (0.1107)  loss_box_reg: 0.1579 (0.1522)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0149 (0.0153)  time: 0.9265  data: 0.0714  max mem: 7043
# Epoch: [8] Total time: 0:03:14 (0.9611 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:01:04  model_time: 0.2827 (0.2827)  evaluator_time: 0.2272 (0.2272)  time: 1.0684  data: 0.5130  max mem: 7043
# Test:  [59/60]  eta: 0:00:00  model_time: 0.2305 (0.2332)  evaluator_time: 0.1570 (0.1998)  time: 0.4427  data: 0.0241  max mem: 7043
# Test: Total time: 0:00:29 (0.4928 s / it)
# Averaged stats: model_time: 0.2305 (0.2332)  evaluator_time: 0.1570 (0.1998)
# Accumulating evaluation results...
# DONE (t=0.13s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.274
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.483
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617
# Epoch: [9]  [  0/202]  eta: 0:07:28  lr: 0.000272  loss: 0.3350 (0.3350)  loss_classifier: 0.1354 (0.1354)  loss_box_reg: 0.1780 (0.1780)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0191 (0.0191)  time: 2.2211  data: 1.2661  max mem: 7043
# Epoch: [9]  [ 20/202]  eta: 0:03:18  lr: 0.000272  loss: 0.2934 (0.2887)  loss_classifier: 0.1131 (0.1160)  loss_box_reg: 0.1587 (0.1549)  loss_objectness: 0.0018 (0.0024)  loss_rpn_box_reg: 0.0152 (0.0154)  time: 1.0334  data: 0.0883  max mem: 7043
# Epoch: [9]  [ 40/202]  eta: 0:02:45  lr: 0.000272  loss: 0.2738 (0.2807)  loss_classifier: 0.1086 (0.1118)  loss_box_reg: 0.1489 (0.1517)  loss_objectness: 0.0012 (0.0020)  loss_rpn_box_reg: 0.0144 (0.0151)  time: 0.9473  data: 0.0680  max mem: 7043
# Epoch: [9]  [ 60/202]  eta: 0:02:21  lr: 0.000272  loss: 0.2681 (0.2781)  loss_classifier: 0.1098 (0.1109)  loss_box_reg: 0.1438 (0.1502)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0143 (0.0151)  time: 0.9396  data: 0.0685  max mem: 7043
# Epoch: [9]  [ 80/202]  eta: 0:02:00  lr: 0.000272  loss: 0.2717 (0.2774)  loss_classifier: 0.1126 (0.1109)  loss_box_reg: 0.1454 (0.1495)  loss_objectness: 0.0014 (0.0019)  loss_rpn_box_reg: 0.0153 (0.0152)  time: 0.9777  data: 0.0746  max mem: 7043
# Epoch: [9]  [100/202]  eta: 0:01:40  lr: 0.000272  loss: 0.2677 (0.2770)  loss_classifier: 0.1090 (0.1104)  loss_box_reg: 0.1437 (0.1495)  loss_objectness: 0.0008 (0.0018)  loss_rpn_box_reg: 0.0145 (0.0153)  time: 0.9844  data: 0.0818  max mem: 7043
# Epoch: [9]  [120/202]  eta: 0:01:20  lr: 0.000272  loss: 0.2620 (0.2757)  loss_classifier: 0.1065 (0.1100)  loss_box_reg: 0.1466 (0.1488)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0130 (0.0151)  time: 0.9466  data: 0.0695  max mem: 7043
# Epoch: [9]  [140/202]  eta: 0:01:00  lr: 0.000272  loss: 0.2775 (0.2773)  loss_classifier: 0.1098 (0.1105)  loss_box_reg: 0.1434 (0.1497)  loss_objectness: 0.0014 (0.0018)  loss_rpn_box_reg: 0.0148 (0.0153)  time: 0.9635  data: 0.0755  max mem: 7043
# Epoch: [9]  [160/202]  eta: 0:00:41  lr: 0.000272  loss: 0.2749 (0.2774)  loss_classifier: 0.1075 (0.1106)  loss_box_reg: 0.1515 (0.1496)  loss_objectness: 0.0022 (0.0019)  loss_rpn_box_reg: 0.0153 (0.0152)  time: 0.9888  data: 0.0792  max mem: 7043
# Epoch: [9]  [180/202]  eta: 0:00:21  lr: 0.000272  loss: 0.2736 (0.2773)  loss_classifier: 0.1024 (0.1104)  loss_box_reg: 0.1411 (0.1494)  loss_objectness: 0.0014 (0.0022)  loss_rpn_box_reg: 0.0138 (0.0153)  time: 0.9506  data: 0.0722  max mem: 7043
# Epoch: [9]  [200/202]  eta: 0:00:01  lr: 0.000272  loss: 0.2763 (0.2769)  loss_classifier: 0.1062 (0.1101)  loss_box_reg: 0.1451 (0.1495)  loss_objectness: 0.0011 (0.0021)  loss_rpn_box_reg: 0.0148 (0.0152)  time: 1.0075  data: 0.0853  max mem: 7043
# Epoch: [9]  [201/202]  eta: 0:00:00  lr: 0.000272  loss: 0.2658 (0.2768)  loss_classifier: 0.1059 (0.1100)  loss_box_reg: 0.1475 (0.1495)  loss_objectness: 0.0011 (0.0021)  loss_rpn_box_reg: 0.0142 (0.0152)  time: 0.9790  data: 0.0840  max mem: 7043
# Epoch: [9] Total time: 0:03:17 (0.9774 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:01:09  model_time: 0.3151 (0.3151)  evaluator_time: 0.2060 (0.2060)  time: 1.1665  data: 0.6048  max mem: 7043
# Test:  [59/60]  eta: 0:00:00  model_time: 0.2329 (0.2354)  evaluator_time: 0.1944 (0.1943)  time: 0.5216  data: 0.0244  max mem: 7043
# Test: Total time: 0:00:29 (0.4889 s / it)
# Averaged stats: model_time: 0.2329 (0.2354)  evaluator_time: 0.1944 (0.1943)
# Accumulating evaluation results...
# DONE (t=0.14s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.277
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.212
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.585
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.615
# Epoch: [10]  [  0/202]  eta: 0:07:15  lr: 0.000232  loss: 0.2692 (0.2692)  loss_classifier: 0.1056 (0.1056)  loss_box_reg: 0.1449 (0.1449)  loss_objectness: 0.0043 (0.0043)  loss_rpn_box_reg: 0.0144 (0.0144)  time: 2.1549  data: 1.2088  max mem: 7043
# Epoch: [10]  [ 20/202]  eta: 0:03:05  lr: 0.000232  loss: 0.2625 (0.2641)  loss_classifier: 0.1040 (0.1041)  loss_box_reg: 0.1447 (0.1437)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0136 (0.0141)  time: 0.9612  data: 0.0716  max mem: 7043
# Epoch: [10]  [ 40/202]  eta: 0:02:41  lr: 0.000232  loss: 0.2638 (0.2664)  loss_classifier: 0.0990 (0.1043)  loss_box_reg: 0.1504 (0.1458)  loss_objectness: 0.0018 (0.0021)  loss_rpn_box_reg: 0.0148 (0.0143)  time: 0.9742  data: 0.0783  max mem: 7043
# Epoch: [10]  [ 60/202]  eta: 0:02:20  lr: 0.000232  loss: 0.2808 (0.2705)  loss_classifier: 0.1098 (0.1064)  loss_box_reg: 0.1448 (0.1475)  loss_objectness: 0.0010 (0.0020)  loss_rpn_box_reg: 0.0150 (0.0146)  time: 0.9772  data: 0.0794  max mem: 7043
# Epoch: [10]  [ 80/202]  eta: 0:01:59  lr: 0.000232  loss: 0.2789 (0.2725)  loss_classifier: 0.1140 (0.1075)  loss_box_reg: 0.1496 (0.1481)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0159 (0.0149)  time: 0.9398  data: 0.0664  max mem: 7043
# Epoch: [10]  [100/202]  eta: 0:01:39  lr: 0.000232  loss: 0.2729 (0.2745)  loss_classifier: 0.1110 (0.1085)  loss_box_reg: 0.1515 (0.1491)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0152 (0.0150)  time: 0.9514  data: 0.0732  max mem: 7043
# Epoch: [10]  [120/202]  eta: 0:01:20  lr: 0.000232  loss: 0.2753 (0.2752)  loss_classifier: 0.1142 (0.1089)  loss_box_reg: 0.1414 (0.1494)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0154 (0.0151)  time: 1.0028  data: 0.0845  max mem: 7043
# Epoch: [10]  [140/202]  eta: 0:01:00  lr: 0.000232  loss: 0.2682 (0.2747)  loss_classifier: 0.1053 (0.1089)  loss_box_reg: 0.1406 (0.1488)  loss_objectness: 0.0021 (0.0021)  loss_rpn_box_reg: 0.0146 (0.0150)  time: 0.9504  data: 0.0716  max mem: 7043
# Epoch: [10]  [160/202]  eta: 0:00:40  lr: 0.000232  loss: 0.2683 (0.2756)  loss_classifier: 0.1014 (0.1089)  loss_box_reg: 0.1540 (0.1496)  loss_objectness: 0.0012 (0.0020)  loss_rpn_box_reg: 0.0157 (0.0152)  time: 0.9480  data: 0.0685  max mem: 7043
# Epoch: [10]  [180/202]  eta: 0:00:21  lr: 0.000232  loss: 0.2729 (0.2755)  loss_classifier: 0.1072 (0.1088)  loss_box_reg: 0.1463 (0.1495)  loss_objectness: 0.0015 (0.0020)  loss_rpn_box_reg: 0.0151 (0.0151)  time: 0.9811  data: 0.0777  max mem: 7043
# Epoch: [10]  [200/202]  eta: 0:00:01  lr: 0.000232  loss: 0.2635 (0.2748)  loss_classifier: 0.1097 (0.1088)  loss_box_reg: 0.1412 (0.1490)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0142 (0.0151)  time: 0.9573  data: 0.0786  max mem: 7043
# Epoch: [10]  [201/202]  eta: 0:00:00  lr: 0.000232  loss: 0.2638 (0.2750)  loss_classifier: 0.1101 (0.1089)  loss_box_reg: 0.1430 (0.1490)  loss_objectness: 0.0007 (0.0021)  loss_rpn_box_reg: 0.0142 (0.0151)  time: 0.9105  data: 0.0687  max mem: 7043
# Epoch: [10] Total time: 0:03:15 (0.9676 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:01:39  model_time: 0.3304 (0.3304)  evaluator_time: 0.5215 (0.5215)  time: 1.6666  data: 0.7417  max mem: 7043
# Test:  [59/60]  eta: 0:00:00  model_time: 0.2319 (0.2343)  evaluator_time: 0.1875 (0.1989)  time: 0.4911  data: 0.0216  max mem: 7043
# Test: Total time: 0:00:29 (0.4941 s / it)
# Averaged stats: model_time: 0.2319 (0.2343)  evaluator_time: 0.1875 (0.1989)
# Accumulating evaluation results...
# DONE (t=0.22s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.244
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627
# Epoch: [11]  [  0/202]  eta: 0:09:16  lr: 0.000197  loss: 0.2399 (0.2399)  loss_classifier: 0.1018 (0.1018)  loss_box_reg: 0.1234 (0.1234)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0143 (0.0143)  time: 2.7573  data: 1.7282  max mem: 7043
# Epoch: [11]  [ 20/202]  eta: 0:03:09  lr: 0.000197  loss: 0.2475 (0.2565)  loss_classifier: 0.1024 (0.1038)  loss_box_reg: 0.1360 (0.1370)  loss_objectness: 0.0018 (0.0019)  loss_rpn_box_reg: 0.0126 (0.0138)  time: 0.9547  data: 0.0726  max mem: 7043
# Epoch: [11]  [ 40/202]  eta: 0:02:40  lr: 0.000197  loss: 0.2889 (0.2692)  loss_classifier: 0.1113 (0.1072)  loss_box_reg: 0.1478 (0.1447)  loss_objectness: 0.0015 (0.0024)  loss_rpn_box_reg: 0.0153 (0.0148)  time: 0.9421  data: 0.0640  max mem: 7043
# Epoch: [11]  [ 60/202]  eta: 0:02:21  lr: 0.000197  loss: 0.2639 (0.2698)  loss_classifier: 0.1013 (0.1072)  loss_box_reg: 0.1504 (0.1457)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0150 (0.0148)  time: 0.9980  data: 0.0824  max mem: 7043
# Epoch: [11]  [ 80/202]  eta: 0:02:01  lr: 0.000197  loss: 0.2675 (0.2699)  loss_classifier: 0.1025 (0.1064)  loss_box_reg: 0.1459 (0.1465)  loss_objectness: 0.0013 (0.0022)  loss_rpn_box_reg: 0.0153 (0.0148)  time: 1.0128  data: 0.0895  max mem: 7043
# Epoch: [11]  [100/202]  eta: 0:01:40  lr: 0.000197  loss: 0.2739 (0.2720)  loss_classifier: 0.1090 (0.1074)  loss_box_reg: 0.1494 (0.1475)  loss_objectness: 0.0010 (0.0021)  loss_rpn_box_reg: 0.0149 (0.0150)  time: 0.9431  data: 0.0694  max mem: 7043
# Epoch: [11]  [120/202]  eta: 0:01:20  lr: 0.000197  loss: 0.2857 (0.2742)  loss_classifier: 0.1144 (0.1084)  loss_box_reg: 0.1525 (0.1486)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0154 (0.0152)  time: 0.9636  data: 0.0673  max mem: 7043
# Epoch: [11]  [140/202]  eta: 0:01:01  lr: 0.000197  loss: 0.2833 (0.2748)  loss_classifier: 0.1125 (0.1086)  loss_box_reg: 0.1494 (0.1490)  loss_objectness: 0.0012 (0.0020)  loss_rpn_box_reg: 0.0152 (0.0152)  time: 0.9857  data: 0.0785  max mem: 7043
# Epoch: [11]  [160/202]  eta: 0:00:41  lr: 0.000197  loss: 0.2712 (0.2740)  loss_classifier: 0.1046 (0.1083)  loss_box_reg: 0.1401 (0.1486)  loss_objectness: 0.0010 (0.0020)  loss_rpn_box_reg: 0.0138 (0.0152)  time: 0.9393  data: 0.0696  max mem: 7043
# Epoch: [11]  [180/202]  eta: 0:00:21  lr: 0.000197  loss: 0.2540 (0.2729)  loss_classifier: 0.1096 (0.1081)  loss_box_reg: 0.1316 (0.1478)  loss_objectness: 0.0008 (0.0020)  loss_rpn_box_reg: 0.0128 (0.0150)  time: 0.9443  data: 0.0703  max mem: 7043
# Epoch: [11]  [200/202]  eta: 0:00:01  lr: 0.000197  loss: 0.2762 (0.2732)  loss_classifier: 0.1129 (0.1081)  loss_box_reg: 0.1444 (0.1480)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0143 (0.0151)  time: 0.9547  data: 0.0740  max mem: 7043
# Epoch: [11]  [201/202]  eta: 0:00:00  lr: 0.000197  loss: 0.2762 (0.2730)  loss_classifier: 0.1129 (0.1080)  loss_box_reg: 0.1444 (0.1479)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0143 (0.0150)  time: 0.9231  data: 0.0724  max mem: 7043
# Epoch: [11] Total time: 0:03:15 (0.9701 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:01:08  model_time: 0.3186 (0.3186)  evaluator_time: 0.3012 (0.3012)  time: 1.1383  data: 0.4980  max mem: 7043
# Test:  [59/60]  eta: 0:00:00  model_time: 0.2321 (0.2359)  evaluator_time: 0.1507 (0.2003)  time: 0.4323  data: 0.0189  max mem: 7043
# Test: Total time: 0:00:29 (0.4956 s / it)
# Averaged stats: model_time: 0.2321 (0.2359)  evaluator_time: 0.1507 (0.2003)
# Accumulating evaluation results...
# DONE (t=0.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.277
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.244
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.625

# %%
torch.save(model.state_dict(), "model_f.pt")
